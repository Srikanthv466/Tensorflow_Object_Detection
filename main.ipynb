# %% [markdown]
# Mounting google colab to google drive

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Creating module root folder

# %%
import os
path = "gdrive/MyDrive/Tensorflow"
os.mkdir(path)

# %%
# %cd '/content/gdrive/MyDrive/Tensorflow'
# Out:
# /content/gdrive/MyDrive/Tensorflow

# %% [markdown]
# Downloading Tensorflow model repository into the root folder

# %%
# !git clone 'https://github.com/tensorflow/models.git'
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 59982, done.
# remote: Counting objects: 100% (1462/1462), done.
# remote: Compressing objects: 100% (518/518), done.
# remote: Total 59982 (delta 990), reused 1340 (delta 917), pack-reused 58520
# Receiving objects: 100% (59982/59982), 573.98 MiB | 17.96 MiB/s, done.
# Resolving deltas: 100% (41622/41622), done.
# Checking out files: 100% (2594/2594), done.

# %% [markdown]
# Installing and Compiling Protobuf

# %%
# !apt-get -y install protobuf-compiler python-pil python-lxml
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# The following additional packages will be installed:
#   python-bs4 python-chardet python-html5lib python-olefile
#   python-pkg-resources python-six python-webencodings
# Suggested packages:
#   python-genshi python-lxml-dbg python-lxml-doc python-pil-doc python-pil-dbg
#   python-setuptools
# The following NEW packages will be installed:
#   python-bs4 python-chardet python-html5lib python-lxml python-olefile
#   python-pil python-pkg-resources python-six python-webencodings
# 0 upgraded, 9 newly installed, 0 to remove and 40 not upgraded.
# Need to get 1,614 kB of archives.
# After this operation, 8,908 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-bs4 all 4.6.0-1 [67.9 kB]
# ...

# %%
# %cd '/content/gdrive/MyDrive/Tensorflow/models/research'
# Out:
# /content/gdrive/MyDrive/Tensorflow/models/research

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %% [markdown]
# COCO API Installation

# %%
# !pip install cython
# !pip install git+https://github.com/philferriere/cocoapi.git
# Out:
# ...
#   Cloning https://github.com/philferriere/cocoapi.git to /tmp/pip-req-build-pzbcewtq
#   Running command git clone -q https://github.com/philferriere/cocoapi.git /tmp/pip-req-build-pzbcewtq
# ERROR: File "setup.py" not found for legacy project git+https://github.com/philferriere/cocoapi.git.

# %% [markdown]
# Installing object detection API

# %%
# !cp object_detection/packages/tf2/setup.py .
# !python -m pip install --use-feature=2020-resolver .
# Out:
# WARNING: --use-feature=2020-resolver no longer has any effect, since it is now the default dependency resolver in pip. This will become an error in pip 21.0.
# Processing /content/gdrive/My Drive/Tensorflow/models/research
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#      |████████████████████████████████| 9.7 MB 12.8 MB/s
# ...
#      |████████████████████████████████| 352 kB 56.0 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 16.3 MB/s
# ...
#      |████████████████████████████████| 54 kB 3.4 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 53.4 MB/s
# ...
#      |████████████████████████████████| 37.1 MB 49 kB/s
# ...

# %% [markdown]
# Testing installation

# %%
# !python object_detection/builders/model_builder_tf2_test.py
# Out:
# 2021-08-06 12:29:40.709050: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Running tests under Python 3.7.11: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2021-08-06 12:29:43.181350: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-08-06 12:29:43.237783: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-06 12:29:43.238381: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %% [markdown]
# Creating a folder named "training_demo" to store all the training files

# %%
os.makedirs('/content/gdrive/MyDrive/Tensorflow/workspace/training_demo')

# %% [markdown]
# Creating subfolders to store pre-trained models, label_map, dataset etc...

# %%
os.makedirs('/content/gdrive/MyDrive/Tensorflow/workspace/training_demo/annotations')
os.makedirs('/content/gdrive/MyDrive/Tensorflow/workspace/training_demo/exported-models')
os.makedirs('/content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images')
os.makedirs('/content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/train')
os.makedirs('/content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/test')
os.makedirs('/content/gdrive/MyDrive/Tensorflow/workspace/training_demo/models')
os.makedirs('/content/gdrive/MyDrive/Tensorflow/workspace/training_demo/pre-trained-models')

# %%
import os
path = "/content"
os.chdir(path)

# %%
# Placed train.zip folder in the training_demo/images/train which consists of images and it's corresponding .xml annotation files
# Extracting the files in the zip file
# !unzip /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/train/train.zip -d /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/train/
# Out:
# Archive:  /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/train/train.zip
#   inflating: /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/train/image_000000001.jpg
#   inflating: /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/train/image_000000001.xml
#   inflating: /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/train/image_000000002.jpg
#   inflating: /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/train/image_000000002.xml
#   inflating: /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/train/image_000000003.jpg
#   inflating: /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/train/image_000000003.xml
#   inflating: /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/train/image_000000004.jpg
#   inflating: /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/train/image_000000004.xml
# ...

# %%
# Placed test.zip folder in the training_demo/images/test which consists of images and it's corresponding .xml annotation files
# Extracting the files in the zip file
# !unzip /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/test/test.zip -d /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/test/
# Out:
# Archive:  /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/test/test.zip
#   inflating: /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/test/image_000001793.jpg
#   inflating: /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/test/image_000001793.xml
#   inflating: /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/test/image_000001794.jpg
#   inflating: /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/test/image_000001794.xml
#   inflating: /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/test/image_000001795.jpg
#   inflating: /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/test/image_000001795.xml
#   inflating: /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/test/image_000001796.jpg
#   inflating: /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/test/image_000001796.xml
# ...

# %%
# Creating a subfolder named preprocessing under Tensorflow/scripts to store generate_tfrecord.py file
os.makedirs('/content/gdrive/MyDrive/Tensorflow/scripts/preprocessing')

# %%
# %cd '/content/gdrive/MyDrive/Tensorflow/scripts/preprocessing'
# Out:
# /content/gdrive/MyDrive/Tensorflow/scripts/preprocessing

# %% [markdown]
# Generating TFRecords

# %%
# !python generate_tfrecord.py -x /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/train -l /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/annotations/label_map.pbtxt -o /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/annotations/train.record
# Out:
# Successfully created the TFRecord file: /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/annotations/train.record

# %%
# !python generate_tfrecord.py -x /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/images/test -l /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/annotations/label_map.pbtxt -o /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/annotations/test.record
# Out:
# Successfully created the TFRecord file: /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/annotations/test.record

# %% [markdown]
# Configuring the training pipeline

# %%
os.makedirs('/content/gdrive/MyDrive/Tensorflow/workspace/training_demo/models/efficientdet_d0')

# %%
# !cp "/content/gdrive/MyDrive/Tensorflow/workspace/training_demo/pre-trained-models/efficientdet_d0_coco17_tpu-32/pipeline.config" "/content/gdrive/MyDrive/Tensorflow/workspace/training_demo/models/efficientdet_d0"

# %%
# !cp "/content/gdrive/MyDrive/Tensorflow/models/research/object_detection/model_main_tf2.py" "/content/gdrive/MyDrive/Tensorflow/workspace/training_demo"

# %%
# %cd '/content/gdrive/MyDrive/Tensorflow/workspace/training_demo'
# Out:
# /content/gdrive/MyDrive/Tensorflow/workspace/training_demo

# %% [markdown]
# Model training

# %%
# !python model_main_tf2.py --model_dir=/content/gdrive/MyDrive/Tensorflow/workspace/training_demo/models/efficientdet_d0 --pipeline_config_path=/content/gdrive/MyDrive/Tensorflow/workspace/training_demo/models/efficientdet_d0/pipeline.config
# Out:
# 2021-08-06 12:49:04.815623: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-08-06 12:49:07.112695: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-08-06 12:49:07.150778: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-06 12:49:07.151371: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-08-06 12:49:07.151430: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...

# %% [markdown]
# Model evaluation

# %%
# !python model_main_tf2.py --model_dir=/content/gdrive/MyDrive/Tensorflow/workspace/training_demo/models/efficientdet_d0 --pipeline_config_path=/content/gdrive/MyDrive/Tensorflow/workspace/training_demo/models/efficientdet_d0/pipeline.config --checkpoint_dir=/content/gdrive/MyDrive/Tensorflow/workspace/training_demo/models/efficientdet_d0
# Out:
# 2021-08-06 17:01:38.865223: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0806 17:01:41.951260 140654118209408 model_lib_v2.py:1082] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0806 17:01:41.951510 140654118209408 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0806 17:01:41.951606 140654118209408 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0806 17:01:41.951690 140654118209408 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# ...

# %%
# !cp '/content/gdrive/MyDrive/Tensorflow/models/research/object_detection/exporter_main_v2.py' "/content/gdrive/MyDrive/Tensorflow/workspace/training_demo"

# %% [markdown]
# Exporting inference graph

# %%
# !python /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/exporter_main_v2.py --input_type image_tensor --pipeline_config_path /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/models/efficientdet_d0/pipeline.config --trained_checkpoint_dir /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/models/efficientdet_d0/ --output_directory /content/gdrive/MyDrive/Tensorflow/workspace/training_demo/exported-models/my_model
# Out:
# 2021-08-06 17:05:43.275047: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-08-06 17:05:45.369049: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-08-06 17:05:45.397243: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-06 17:05:45.397857: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-08-06 17:05:45.397906: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...
